# %% [markdown]
# # Tutorial on Hand Written Digit Recognition
#
# In this tutorial we will go through the basic use case of MXNet and also touch on some advanced usages. This example is based on the MNIST dataset, which contains 70,000 images of hand written characters with 28-by-28 pixel size.
#
# This tutorial covers the following topics:
# - network definition.
# - Variable naming.
# - Basic data loading and training with feed-forward deep neural networks.
# - Monitoring intermediate outputs for debuging.
# - Custom training loop for advanced models.
#
# First let's import the modules and setup logging:

# %%
# %matplotlib inline

import mxnet as mx
import numpy as np
import cv2
import matplotlib.pyplot as plt
import logging

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
# Out:
# /home/ttong/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py:46: DeprecationWarning: OpenSSL.rand is deprecated - you should use os.urandom instead
#   import OpenSSL.SSL

# %% [markdown]
# ## Network Definition
# Now we can start constructing our network:

# %%
# Variables are place holders for input arrays. We give each variable a unique name.
data = mx.symbol.Variable('data')

# The input is fed to a fully connected layer that computes Y=WX+b.
# This is the main computation module in the network.
# Each layer also needs an unique name. We'll talk more about naming in the next section.
fc1  = mx.symbol.FullyConnected(data = data, name='fc1', num_hidden=128)
# Activation layers apply a non-linear function on the previous layer's output.
# Here we use Rectified Linear Unit (ReLU) that computes Y = max(X, 0).
act1 = mx.symbol.Activation(data = fc1, name='relu1', act_type="relu")

fc2  = mx.symbol.FullyConnected(data = act1, name = 'fc2', num_hidden = 64)
act2 = mx.symbol.Activation(data = fc2, name='relu2', act_type="relu")

fc3  = mx.symbol.FullyConnected(data = act2, name='fc3', num_hidden=10)
# Finally we have a loss layer that compares the network's output with label and generates gradient signals.
mlp  = mx.symbol.SoftmaxOutput(data = fc3, name = 'softmax')

# %% [markdown]
# We can visualize the network we just defined with MXNet's visualization module:

# %%
mx.viz.plot_network(mlp)

# %% [markdown]
# ## Variable Naming
#
# MXNet requires variable names to follow certain conventions:
# - All input arrays have a name. This includes inputs (data & label) and model parameters (weight, bias, etc).
# - Arrays can be renamed by creating named variable. Otherwise, a default name is given as 'SymbolName_ArrayName'. For example, FullyConnected symbol fc1's weight array is named as 'fc1_weight'.
# - Although you can also rename weight arrays with variables, weight array's name should always end with '_weight' and bias array '_bias'. MXNet relies on the suffixes of array names to correctly initialize & update them.
#
# Call list_arguments method on a symbol to get the names of all its inputs:

# %%
mlp.list_arguments()
# Out:
# ['data',
#  'fc1_weight',
#  'fc1_bias',
#  'fc2_weight',
#  'fc2_bias',
#  'fc3_weight',
#  'fc3_bias',
#  'softmax_label']

# %% [markdown]
# ## Data Loading
#
# We fetch and load the MNIST dataset and partition it into two sets: 60000 examples for training and 10000 examples for testing. We also visualize a few examples to get an idea of what the dataset looks like.

# %%
from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')
np.random.seed(1234) # set seed for deterministic ordering
p = np.random.permutation(mnist.data.shape[0])
X = mnist.data[p]
Y = mnist.target[p]

for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X[i].reshape((28,28)), cmap='Greys_r')
    plt.axis('off')

plt.show()

X = X.astype(np.float32)/255
X_train = X[:60000]
X_test = X[60000:]
Y_train = Y[:60000]
Y_test = Y[60000:]

# %% [markdown]
# Now we can create data iterators from our MNIST data. A data iterator returns a batch of data examples each time for the network to process. MXNet provide a suite of basic DataIters for parsing different data format. Here we use NDArrayIter, which wraps around a numpy array and each time slice a chunk from it along the first dimension.

# %%
batch_size = 100
train_iter = mx.io.NDArrayIter(X_train, Y_train, batch_size=batch_size)
test_iter = mx.io.NDArrayIter(X_test, Y_test, batch_size=batch_size)

# %% [markdown]
# ## Training
#
# With the network and data source defined, we can finally start to train our model. We do this with MXNet's convenience wrapper for feed forward neural networks (it can also be made to handle RNNs with explicit unrolling).

# %%
model = mx.model.FeedForward(
    ctx = mx.cpu(0),      # Run on GPU 0
    symbol = mlp,         # Use the network we just defined
    num_epoch = 10,       # Train for 10 epochs
    learning_rate = 0.1,  # Learning rate
    momentum = 0.9,       # Momentum for SGD with momentum
    wd = 0.00001)         # Weight decay for regularization
model.fit(
    X=train_iter,  # Training data set
    eval_data=test_iter,  # Testing data set. MXNet computes scores on test set every epoch
    batch_end_callback = mx.callback.Speedometer(batch_size, 200))  # Logging module to print out progress
# Out:
# /home/ttong/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:7: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
# /home/ttong/anaconda3/lib/python3.6/site-packages/mxnet/model.py:547: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.
#   self.initializer(k, v)
# INFO:root:Start training with [cpu(0)]
# INFO:root:Epoch[0] Batch [200]	Speed: 29490.04 samples/sec	accuracy=0.441500
# INFO:root:Epoch[0] Batch [400]	Speed: 37741.61 samples/sec	accuracy=0.905900
# INFO:root:Epoch[0] Batch [600]	Speed: 32518.26 samples/sec	accuracy=0.939500
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=1.885
# INFO:root:Epoch[0] Validation-accuracy=0.948500
# INFO:root:Epoch[1] Batch [200]	Speed: 35949.16 samples/sec	accuracy=0.949400
# INFO:root:Epoch[1] Batch [400]	Speed: 39454.34 samples/sec	accuracy=0.961300
# INFO:root:Epoch[1] Batch [600]	Speed: 23010.81 samples/sec	accuracy=0.963400
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=1.939
# INFO:root:Epoch[1] Validation-accuracy=0.961300
# INFO:root:Epoch[2] Batch [200]	Speed: 35425.04 samples/sec	accuracy=0.967100
# INFO:root:Epoch[2] Batch [400]	Speed: 39687.78 samples/sec	accuracy=0.973500
# INFO:root:Epoch[2] Batch [600]	Speed: 29769.33 samples/sec	accuracy=0.973250
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=1.747
# INFO:root:Epoch[2] Validation-accuracy=0.965800
# INFO:root:Epoch[3] Batch [200]	Speed: 37260.16 samples/sec	accuracy=0.973650
# INFO:root:Epoch[3] Batch [400]	Speed: 23066.23 samples/sec	accuracy=0.977250
# INFO:root:Epoch[3] Batch [600]	Speed: 33045.19 samples/sec	accuracy=0.976850
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=2.017
# INFO:root:Epoch[3] Validation-accuracy=0.972000
# INFO:root:Epoch[4] Batch [200]	Speed: 33420.71 samples/sec	accuracy=0.980000
# INFO:root:Epoch[4] Batch [400]	Speed: 17365.24 samples/sec	accuracy=0.982300
# INFO:root:Epoch[4] Batch [600]	Speed: 39365.45 samples/sec	accuracy=0.984150
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=2.265
# INFO:root:Epoch[4] Validation-accuracy=0.968300
# INFO:root:Epoch[5] Batch [200]	Speed: 37891.63 samples/sec	accuracy=0.983350
# INFO:root:Epoch[5] Batch [400]	Speed: 21222.43 samples/sec	accuracy=0.984500
# INFO:root:Epoch[5] Batch [600]	Speed: 36224.57 samples/sec	accuracy=0.986350
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=2.029
# INFO:root:Epoch[5] Validation-accuracy=0.970800
# INFO:root:Epoch[6] Batch [200]	Speed: 26912.47 samples/sec	accuracy=0.984050
# INFO:root:Epoch[6] Batch [400]	Speed: 33305.86 samples/sec	accuracy=0.985600
# INFO:root:Epoch[6] Batch [600]	Speed: 21733.94 samples/sec	accuracy=0.985350
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=2.271
# INFO:root:Epoch[6] Validation-accuracy=0.968300
# INFO:root:Epoch[7] Batch [200]	Speed: 12438.53 samples/sec	accuracy=0.984800
# INFO:root:Epoch[7] Batch [400]	Speed: 26172.28 samples/sec	accuracy=0.987750
# INFO:root:Epoch[7] Batch [600]	Speed: 28796.49 samples/sec	accuracy=0.988850
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=3.077
# INFO:root:Epoch[7] Validation-accuracy=0.975600
# INFO:root:Epoch[8] Batch [200]	Speed: 20711.03 samples/sec	accuracy=0.988550
# INFO:root:Epoch[8] Batch [400]	Speed: 18283.26 samples/sec	accuracy=0.990600
# INFO:root:Epoch[8] Batch [600]	Speed: 28012.90 samples/sec	accuracy=0.991650
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=2.780
# INFO:root:Epoch[8] Validation-accuracy=0.973700
# INFO:root:Epoch[9] Batch [200]	Speed: 35132.51 samples/sec	accuracy=0.988900
# INFO:root:Epoch[9] Batch [400]	Speed: 36166.80 samples/sec	accuracy=0.988200
# INFO:root:Epoch[9] Batch [600]	Speed: 29242.25 samples/sec	accuracy=0.991750
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=1.813
# INFO:root:Epoch[9] Validation-accuracy=0.973800

# %% [markdown]
# ## Evaluation
#
# After the model is trained, we can evaluate it on a held out test set.
# First, lets classity a sample image:

# %%
plt.imshow((X_test[0].reshape((28,28))*255).astype(np.uint8), cmap='Greys_r')
plt.show()
print('Result:', model.predict(X_test[0:1])[0].argmax())
# Out:
# Result: 7

# %% [markdown]
# We can also evaluate the model's accuracy on the entire test set:

# %%
print('Accuracy:', model.score(test_iter)*100, '%')
# Out:
# Accuracy: 97.38 %

# %% [markdown]
# Now, try if your model recognizes your own hand writing.
#
# Write a digit from 0 to 9 in the box below. Try to put your digit in the middle of the box.

# %%
# run hand drawing test
from IPython.display import HTML

def classify(img):
    img = img[len('data:image/png;base64,'):].decode('base64')
    img = cv2.imdecode(np.fromstring(img, np.uint8), -1)
    img = cv2.resize(img[:,:,3], (28,28))
    img = img.astype(np.float32).reshape((1, 784))/255.0
    return model.predict(img)[0].argmax()

html = """<style type="text/css">canvas { border: 1px solid black; }</style><div id="board"><canvas id="myCanvas" width="100px" height="100px">Sorry, your browser doesn't support canvas technology.</canvas><p><button id="classify" onclick="classify()">Classify</button><button id="clear" onclick="myClear()">Clear</button>Result: <input type="text" id="result_output" size="5" value=""></p></div>"""
script = """<script type="text/JavaScript" src="https://ajax.googleapis.com/ajax/libs/jquery/1.4.2/jquery.min.js?ver=1.4.2"></script><script type="text/javascript">function init() {var myCanvas = document.getElementById("myCanvas");var curColor = $('#selectColor option:selected').val();if(myCanvas){var isDown = false;var ctx = myCanvas.getContext("2d");var canvasX, canvasY;ctx.lineWidth = 8;$(myCanvas).mousedown(function(e){isDown = true;ctx.beginPath();var parentOffset = $(this).parent().offset(); canvasX = e.pageX - parentOffset.left;canvasY = e.pageY - parentOffset.top;ctx.moveTo(canvasX, canvasY);}).mousemove(function(e){if(isDown != false) {var parentOffset = $(this).parent().offset(); canvasX = e.pageX - parentOffset.left;canvasY = e.pageY - parentOffset.top;ctx.lineTo(canvasX, canvasY);ctx.strokeStyle = curColor;ctx.stroke();}}).mouseup(function(e){isDown = false;ctx.closePath();});}$('#selectColor').change(function () {curColor = $('#selectColor option:selected').val();});}init();function handle_output(out) {document.getElementById("result_output").value = out.content.data["text/plain"];}function classify() {var kernel = IPython.notebook.kernel;var myCanvas = document.getElementById("myCanvas");data = myCanvas.toDataURL('image/png');document.getElementById("result_output").value = "";kernel.execute("classify('" + data +"')",  { 'iopub' : {'output' : handle_output}}, {silent:false});}function myClear() {var myCanvas = document.getElementById("myCanvas");myCanvas.getContext("2d").clearRect(0, 0, myCanvas.width, myCanvas.height);}</script>"""
HTML(html+script)
# Out:
# <style type="text/css">canvas { border: 1px solid black; }</style><div id="board"><canvas id="myCanvas" width="100px" height="100px">Sorry, your browser doesn't support canvas technology.</canvas><p><button id="classify" onclick="classify()">Classify</button><button id="clear" onclick="myClear()">Clear</button>Result: <input type="text" id="result_output" size="5" value=""></p></div><script type="text/JavaScript" src="https://ajax.googleapis.com/ajax/libs/jquery/1.4.2/jquery.min.js?ver=1.4.2"></script><script type="text/javascript">function init() {var myCanvas = document.getElementById("myCanvas");var curColor = $('#selectColor option:selected').val();if(myCanvas){var isDown = false;var ctx = myCanvas.getContext("2d");var canvasX, canvasY;ctx.lineWidth = 8;$(myCanvas).mousedown(function(e){isDown = true;ctx.beginPath();var parentOffset = $(this).parent().offset(); canvasX = e.pageX - parentOffset.left;canvasY = e.pageY - parentOffset.top;ctx.moveTo(canvasX, canvasY);}).mousemove(function(e){if(isDown != false) {var parentOffset = $(this).parent().offset(); canvasX = e.pageX - parentOffset.left;canvasY = e.pageY - parentOffset.top;ctx.lineTo(canvasX, canvasY);ctx.strokeStyle = curColor;ctx.stroke();}}).mouseup(function(e){isDown = false;ctx.closePath();});}$('#selectColor').change(function () {curColor = $('#selectColor option:selected').val();});}init();function handle_output(out) {document.getElementById("result_output").value = out.content.data["text/plain"];}function classify() {var kernel = IPython.notebook.kernel;var myCanvas = document.getElementById("myCanvas");data = myCanvas.toDataURL('image/png');document.getElementById("result_output").value = "";kernel.execute("classify('" + data +"')",  { 'iopub' : {'output' : handle_output}}, {silent:false});}function myClear() {var myCanvas = document.getElementById("myCanvas");myCanvas.getContext("2d").clearRect(0, 0, myCanvas.width, myCanvas.height);}</script>

# %% [markdown]
# ## Debugging
#
# DNNs can perform poorly for a lot of reasons, like learning rate too big/small, initialization too big/small, network structure not reasonable, etc. When this happens it's often helpful to print out the weights and intermediate outputs to understand what's going on. MXNet provides a monitor utility that does this:

# %%
def norm_stat(d):
    """The statistics you want to see.
    We compute the L2 norm here but you can change it to anything you like."""
    return mx.nd.norm(d)/np.sqrt(d.size)
mon = mx.mon.Monitor(
    100,                 # Print every 100 batches
    norm_stat,           # The statistics function defined above
    pattern='.*weight',  # A regular expression. Only arrays with name matching this pattern will be included.
    sort=True)           # Sort output by name
model = mx.model.FeedForward(ctx = mx.cpu(0), symbol = mlp, num_epoch = 1,
                             learning_rate = 0.1, momentum = 0.9, wd = 0.00001)
model.fit(X=train_iter, eval_data=test_iter, monitor=mon,  # Set the monitor here
          batch_end_callback = mx.callback.Speedometer(100, 100))
# Out:
# /home/ttong/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:11: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
# /home/ttong/anaconda3/lib/python3.6/site-packages/mxnet/model.py:547: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.
#   self.initializer(k, v)
# INFO:root:Start training with [cpu(0)]
# INFO:root:Batch:       1 fc1_backward_weight            0.000579228
# INFO:root:Batch:       1 fc1_weight                     0.00577974
# INFO:root:Batch:       1 fc2_backward_weight            0.0018464
# INFO:root:Batch:       1 fc2_weight                     0.00574704
# INFO:root:Batch:       1 fc3_backward_weight            0.00538812
# INFO:root:Batch:       1 fc3_weight                     0.00581161
# INFO:root:Epoch[0] Batch [100]	Speed: 29717.92 samples/sec	accuracy=0.163500
# INFO:root:Batch:     101 fc1_backward_weight            0.115672
# INFO:root:Batch:     101 fc1_weight                     0.00887543
# INFO:root:Batch:     101 fc2_backward_weight            0.338121
# INFO:root:Batch:     101 fc2_weight                     0.02348
# INFO:root:Batch:     101 fc3_backward_weight            2.62167
# INFO:root:Batch:     101 fc3_weight                     0.0881213
# INFO:root:Epoch[0] Batch [200]	Speed: 29394.48 samples/sec	accuracy=0.723300
# INFO:root:Batch:     201 fc1_backward_weight            0.279511
# INFO:root:Batch:     201 fc1_weight                     0.02407
# INFO:root:Batch:     201 fc2_backward_weight            0.672216
# INFO:root:Batch:     201 fc2_weight                     0.0496466
# INFO:root:Batch:     201 fc3_backward_weight            1.76499
# INFO:root:Batch:     201 fc3_weight                     0.218324
# INFO:root:Epoch[0] Batch [300]	Speed: 30542.86 samples/sec	accuracy=0.897400
# INFO:root:Batch:     301 fc1_backward_weight            0.137541
# INFO:root:Batch:     301 fc1_weight                     0.030687
# INFO:root:Batch:     301 fc2_backward_weight            0.251968
# INFO:root:Batch:     301 fc2_weight                     0.0625244
# INFO:root:Batch:     301 fc3_backward_weight            0.547697
# INFO:root:Batch:     301 fc3_weight                     0.239656
# INFO:root:Epoch[0] Batch [400]	Speed: 6965.65 samples/sec	accuracy=0.927800
# INFO:root:Batch:     401 fc1_backward_weight            0.074789
# INFO:root:Batch:     401 fc1_weight                     0.0351427
# INFO:root:Batch:     401 fc2_backward_weight            0.155276
# INFO:root:Batch:     401 fc2_weight                     0.0700585
# INFO:root:Batch:     401 fc3_backward_weight            0.37336
# INFO:root:Batch:     401 fc3_weight                     0.248999
# INFO:root:Epoch[0] Batch [500]	Speed: 27543.71 samples/sec	accuracy=0.936100
# INFO:root:Batch:     501 fc1_backward_weight            0.157669
# INFO:root:Batch:     501 fc1_weight                     0.0390462
# INFO:root:Batch:     501 fc2_backward_weight            0.320947
# INFO:root:Batch:     501 fc2_weight                     0.0761403
# INFO:root:Batch:     501 fc3_backward_weight            0.756256
# INFO:root:Batch:     501 fc3_weight                     0.253823
# INFO:root:Epoch[0] Batch [600]	Speed: 15478.59 samples/sec	accuracy=0.945500
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=3.482
# INFO:root:Epoch[0] Validation-accuracy=0.951100

# %% [markdown]
# ## Under the hood: Custom Training Loop
#
# `mx.model.FeedForward` is a convenience wrapper for training standard feed forward networks. What if the model you are working with is more complicated? With MXNet, you can easily control every aspect of training by writing your own training loop.
#
# Neural network training typically has 3 steps: forward, backward (gradient), and update. With custom training loop, you can control the details in each step as while as insert complicated computations in between. You can also connect multiple networks together.

# %%
# ==================Binding=====================
# The symbol we created is only a graph description.
# To run it, we first need to allocate memory and create an executor by 'binding' it.
# In order to bind a symbol, we need at least two pieces of information: context and input shapes.
# Context specifies which device the executor runs on, e.g. cpu, GPU0, GPU1, etc.
# Input shapes define the executor's input array dimensions.
# MXNet then run automatic shape inference to determine the dimensions of intermediate and output arrays.

# data iterators defines shapes of its output with provide_data and provide_label property.
input_shapes = dict(train_iter.provide_data+train_iter.provide_label)
print('input_shapes', input_shapes)
# We use simple_bind to let MXNet allocate memory for us.
# You can also allocate memory youself and use bind to pass it to MXNet.
exe = mlp.simple_bind(ctx=mx.cpu(0), **input_shapes)

# ===============Initialization=================
# First we get handle to input arrays
arg_arrays = dict(zip(mlp.list_arguments(), exe.arg_arrays))
data = arg_arrays[train_iter.provide_data[0][0]]
label = arg_arrays[train_iter.provide_label[0][0]]

# We initialize the weights with uniform distribution on (-0.01, 0.01).
init = mx.init.Uniform(scale=0.01)
for name, arr in arg_arrays.items():
    if name not in input_shapes:
        init(name, arr)
    
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=0.1,
    momentum=0.9,
    wd=0.00001,
    rescale_grad=1.0/train_iter.batch_size)
updater = mx.optimizer.get_updater(opt)

# Finally we need a metric to print out training progress
metric = mx.metric.Accuracy()

# Training loop begines
for epoch in range(10):
    train_iter.reset()
    metric.reset()
    t = 0
    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]
        
        # Forward
        exe.forward(is_train=True)
        
        # You perform operations on exe.outputs here if you need to.
        # For example, you can stack a CRF on top of a neural network.
        
        # Backward
        exe.backward()
        
        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)
        metric.update(batch.label, exe.outputs)
        t += 1
        if t % 100 == 0:
            print('epoch:', epoch, 'iter:', t, 'metric:', metric.get())
# Out:
# input_shapes {'data': (100, 784), 'softmax_label': (100,)}
# /home/ttong/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:26: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.
# epoch: 0 iter: 100 metric: ('accuracy', 0.15629999999999999)
# epoch: 0 iter: 200 metric: ('accuracy', 0.433)
# epoch: 0 iter: 300 metric: ('accuracy', 0.58766666666666667)
# epoch: 0 iter: 400 metric: ('accuracy', 0.67182500000000001)
# epoch: 0 iter: 500 metric: ('accuracy', 0.72382000000000002)
# epoch: 0 iter: 600 metric: ('accuracy', 0.76061666666666672)
# epoch: 1 iter: 100 metric: ('accuracy', 0.94920000000000004)
# epoch: 1 iter: 200 metric: ('accuracy', 0.95045000000000002)
# epoch: 1 iter: 300 metric: ('accuracy', 0.95356666666666667)
# epoch: 1 iter: 400 metric: ('accuracy', 0.95640000000000003)
# epoch: 1 iter: 500 metric: ('accuracy', 0.95706000000000002)
# epoch: 1 iter: 600 metric: ('accuracy', 0.95876666666666666)
# epoch: 2 iter: 100 metric: ('accuracy', 0.96819999999999995)
# epoch: 2 iter: 200 metric: ('accuracy', 0.96835000000000004)
# epoch: 2 iter: 300 metric: ('accuracy', 0.97073333333333334)
# epoch: 2 iter: 400 metric: ('accuracy', 0.97140000000000004)
# epoch: 2 iter: 500 metric: ('accuracy', 0.97148000000000001)
# epoch: 2 iter: 600 metric: ('accuracy', 0.97248333333333337)
# epoch: 3 iter: 100 metric: ('accuracy', 0.97829999999999995)
# epoch: 3 iter: 200 metric: ('accuracy', 0.97709999999999997)
# epoch: 3 iter: 300 metric: ('accuracy', 0.9778)
# epoch: 3 iter: 400 metric: ('accuracy', 0.97865000000000002)
# epoch: 3 iter: 500 metric: ('accuracy', 0.97884000000000004)
# epoch: 3 iter: 600 metric: ('accuracy', 0.97933333333333328)
# epoch: 4 iter: 100 metric: ('accuracy', 0.98240000000000005)
# epoch: 4 iter: 200 metric: ('accuracy', 0.98150000000000004)
# epoch: 4 iter: 300 metric: ('accuracy', 0.98216666666666663)
# epoch: 4 iter: 400 metric: ('accuracy', 0.98292500000000005)
# epoch: 4 iter: 500 metric: ('accuracy', 0.98306000000000004)
# epoch: 4 iter: 600 metric: ('accuracy', 0.98324999999999996)
# epoch: 5 iter: 100 metric: ('accuracy', 0.98499999999999999)
# epoch: 5 iter: 200 metric: ('accuracy', 0.98494999999999999)
# epoch: 5 iter: 300 metric: ('accuracy', 0.98516666666666663)
# epoch: 5 iter: 400 metric: ('accuracy', 0.98502500000000004)
# epoch: 5 iter: 500 metric: ('accuracy', 0.9849)
# epoch: 5 iter: 600 metric: ('accuracy', 0.98513333333333331)
# epoch: 6 iter: 100 metric: ('accuracy', 0.98250000000000004)
# epoch: 6 iter: 200 metric: ('accuracy', 0.98404999999999998)
# epoch: 6 iter: 300 metric: ('accuracy', 0.98486666666666667)
# epoch: 6 iter: 400 metric: ('accuracy', 0.98522500000000002)
# epoch: 6 iter: 500 metric: ('accuracy', 0.98558000000000001)
# epoch: 6 iter: 600 metric: ('accuracy', 0.98604999999999998)
# epoch: 7 iter: 100 metric: ('accuracy', 0.98550000000000004)
# epoch: 7 iter: 200 metric: ('accuracy', 0.98480000000000001)
# epoch: 7 iter: 300 metric: ('accuracy', 0.98653333333333337)
# epoch: 7 iter: 400 metric: ('accuracy', 0.98645000000000005)
# epoch: 7 iter: 500 metric: ('accuracy', 0.98687999999999998)
# epoch: 7 iter: 600 metric: ('accuracy', 0.98706666666666665)
# epoch: 8 iter: 100 metric: ('accuracy', 0.98660000000000003)
# epoch: 8 iter: 200 metric: ('accuracy', 0.98719999999999997)
# epoch: 8 iter: 300 metric: ('accuracy', 0.98780000000000001)
# epoch: 8 iter: 400 metric: ('accuracy', 0.98797500000000005)
# epoch: 8 iter: 500 metric: ('accuracy', 0.98794000000000004)
# epoch: 8 iter: 600 metric: ('accuracy', 0.98858333333333337)
# epoch: 9 iter: 100 metric: ('accuracy', 0.99109999999999998)
# epoch: 9 iter: 200 metric: ('accuracy', 0.98950000000000005)
# epoch: 9 iter: 300 metric: ('accuracy', 0.98960000000000004)
# epoch: 9 iter: 400 metric: ('accuracy', 0.99007500000000004)
# epoch: 9 iter: 500 metric: ('accuracy', 0.99019999999999997)
# epoch: 9 iter: 600 metric: ('accuracy', 0.9906166666666667)

# %% [markdown]
# ## New Operators
#
# MXNet provides a repository of common operators (or layers). However, new models often require new layers. There are several ways to [create new operators](https://mxnet.readthedocs.org/en/latest/tutorial/new_op_howto.html) with MXNet. Here we talk about the easiest way: pure python.

# %%
# Define custom softmax operator
class NumpySoftmax(mx.operator.NumpyOp):
    def __init__(self):
        # Call the parent class constructor. 
        # Because NumpySoftmax is a loss layer, it doesn't need gradient input from layers above.
        super(NumpySoftmax, self).__init__(need_top_grad=False)
    
    def list_arguments(self):
        # Define the input to NumpySoftmax.
        return ['data', 'label']

    def list_outputs(self):
        # Define the output.
        return ['output']

    def infer_shape(self, in_shape):
        # Calculate the dimensions of the output (and missing inputs) from (some) input shapes.
        data_shape = in_shape[0]  # shape of first argument 'data'
        label_shape = (in_shape[0][0],)  # 'label' should be one dimensional and has batch_size instances.
        output_shape = in_shape[0] # 'output' dimension is the same as the input.
        return [data_shape, label_shape], [output_shape]

    def forward(self, in_data, out_data):
        x = in_data[0]  # 'data'
        y = out_data[0]  # 'output'
        
        # Compute softmax
        y[:] = np.exp(x - x.max(axis=1).reshape((x.shape[0], 1)))
        y /= y.sum(axis=1).reshape((x.shape[0], 1))

    def backward(self, out_grad, in_data, out_data, in_grad):
        l = in_data[1]  # 'label'
        l = l.reshape((l.size,)).astype(np.int)  # cast to int
        y = out_data[0]  # 'output'
        dx = in_grad[0]  # gradient for 'data'
        
        # Compute gradient
        dx[:] = y
        dx[np.arange(l.shape[0]), l] -= 1.0

numpy_softmax = NumpySoftmax()

data = mx.symbol.Variable('data')
fc1 = mx.symbol.FullyConnected(data = data, name='fc1', num_hidden=128)
act1 = mx.symbol.Activation(data = fc1, name='relu1', act_type="relu")
fc2 = mx.symbol.FullyConnected(data = act1, name = 'fc2', num_hidden = 64)
act2 = mx.symbol.Activation(data = fc2, name='relu2', act_type="relu")
fc3 = mx.symbol.FullyConnected(data = act2, name='fc3', num_hidden=10)
# Use the new operator we just defined instead of the standard softmax operator.
mlp = numpy_softmax(data=fc3, name = 'softmax')

model = mx.model.FeedForward(ctx = mx.cpu(0), symbol = mlp, num_epoch = 2,
                             learning_rate = 0.1, momentum = 0.9, wd = 0.00001)
model.fit(X=train_iter, eval_data=test_iter,
          batch_end_callback = mx.callback.Speedometer(100, 100))
# Out:
# /home/ttong/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:53: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
# /home/ttong/anaconda3/lib/python3.6/site-packages/mxnet/model.py:547: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.
#   self.initializer(k, v)
# INFO:root:Start training with [cpu(0)]
# INFO:root:Epoch[0] Batch [100]	Speed: 5325.98 samples/sec	accuracy=0.160300
# INFO:root:Epoch[0] Batch [200]	Speed: 27316.57 samples/sec	accuracy=0.735000
# INFO:root:Epoch[0] Batch [300]	Speed: 5300.25 samples/sec	accuracy=0.894000
# INFO:root:Epoch[0] Batch [400]	Speed: 6721.31 samples/sec	accuracy=0.934200
# INFO:root:Epoch[0] Batch [500]	Speed: 6688.47 samples/sec	accuracy=0.939500
# INFO:root:Epoch[0] Batch [600]	Speed: 33651.73 samples/sec	accuracy=0.948400
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=7.546
# INFO:root:Epoch[0] Validation-accuracy=0.950100
# INFO:root:Epoch[1] Batch [100]	Speed: 21003.38 samples/sec	accuracy=0.949700
# INFO:root:Epoch[1] Batch [200]	Speed: 1762.23 samples/sec	accuracy=0.951700
# INFO:root:Epoch[1] Batch [300]	Speed: 1564.57 samples/sec	accuracy=0.957000
# INFO:root:Epoch[1] Batch [400]	Speed: 17011.86 samples/sec	accuracy=0.964100
# INFO:root:Epoch[1] Batch [500]	Speed: 28202.18 samples/sec	accuracy=0.964200
# INFO:root:Epoch[1] Batch [600]	Speed: 22544.68 samples/sec	accuracy=0.968300
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=13.995
# INFO:root:Epoch[1] Validation-accuracy=0.964800

# %% [markdown]
# ## Further Readings
#
# - More state-of-the-art cnn models are available at [mxnet/example/image-classification](https://github.com/dmlc/mxnet/tree/master/example/image-classification)
